# %%
'''
Name         : Rupesh Garsondiya 
github       : @Rupeshgarsondiya
Organization : L.J University
'''
# Out:
# '\nName         : Rupesh Garsondiya \ngithub       : @Rupeshgarsondiya\nOrganization : L.J University\n'

# %%
# import library
